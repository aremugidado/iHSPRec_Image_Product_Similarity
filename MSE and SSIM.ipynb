# %%
# import the necessary packages
from skimage.metrics import structural_similarity as ssim
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
def mse(imageA, imageB):
	# the 'Mean Squared Error' between the two images is the
	# sum of the squared difference between the two images;
	# NOTE: the two images must have the same dimension
	err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
	err /= float(imageA.shape[0] * imageA.shape[1])
	
	# return the MSE, the lower the error, the more "similar"
	# the two images are
	return err
def compare_images(imageA, imageB, title):
	# compute the mean squared error and structural similarity
	# index for the images
	m = mse(imageA, imageB)
	s = ssim(imageA, imageB)
	# setup the figure
	fig = plt.figure(title)
	plt.suptitle("MSE: %.2f, SSIM: %.2f" % (m, s))
	# show first image
	ax = fig.add_subplot(1, 2, 1)
	plt.imshow(imageA, cmap = plt.cm.gray)
	plt.axis("off")
	# show the second image
	ax = fig.add_subplot(1, 2, 2)
	plt.imshow(imageB, cmap = plt.cm.gray)
	plt.axis("off")
	# show the images
	plt.show()

# %%
# load the images -- the original, the original + contrast,
# and the original + photoshop
flipflop = cv2.imread("flipflop.png")
slippers = cv2.imread("slippers.png")
mouse = cv2.imread("mouse.png")
# convert the images to grayscale
flipflop = cv2.cvtColor(flipflop, cv2.COLOR_BGR2GRAY)
slippers = cv2.cvtColor(slippers, cv2.COLOR_BGR2GRAY)
mouse = cv2.cvtColor(mouse, cv2.COLOR_BGR2GRAY)

# %%
print(flipflop.shape)
# Out:
# (132, 360)

# %%
cv2.imwrite('newflipflop.jpg', flipflop)
# Out:
# True

# %%
cv2.imwrite('newslippers.jpg', slippers)
#img = slippers.save('newslippers.jpg')
# Out:
# True

# %%
cv2.imwrite('newmouse.jpg', mouse)
#img = mouse.save('newmouse.jpg')
# Out:
# True

# %%
# load the images -- the original, the original + contrast,
# and the original + photoshop
flipflop = cv2.imread("flipflop.png")
slippers = cv2.imread("slippers.png")
mouse = cv2.imread("mouse.png")
# convert the images to grayscale
flipflop = cv2.cvtColor(flipflop, cv2.COLOR_BGR2GRAY)
slippers = cv2.cvtColor(slippers, cv2.COLOR_BGR2GRAY)
mouse = cv2.cvtColor(mouse, cv2.COLOR_BGR2GRAY)

# %%
# initialize the figure
fig = plt.figure("Images")
images = ("flipflop", flipflop), ("slippers", slippers), ("mouse", mouse)
# loop over the images
for (i, (name, image)) in enumerate(images):
	# show the image
	ax = fig.add_subplot(1, 3, i + 1)
	ax.set_title(name)
	plt.imshow(image, cmap = plt.cm.gray)
	plt.axis("off")
# show the figure
plt.show()
# compare the images
compare_images(flipflop, flipflop, "flipflop vs. flipflop")
compare_images(flipflop, slippers, "flipflop vs. slippers")
compare_images(flipflop, mouse, "flipflop vs. mouse")

# %%
# load the images -- the original, the original + contrast,
# and the original + photoshop
flipflop = cv2.imread("flipflop.png")
pad = cv2.imread("pad.png")
mouse = cv2.imread("mouse.png")
# convert the images to grayscale
flipflop = cv2.cvtColor(flipflop, cv2.COLOR_BGR2GRAY)
pad = cv2.cvtColor(pad, cv2.COLOR_BGR2GRAY)
mouse = cv2.cvtColor(mouse, cv2.COLOR_BGR2GRAY)

# %%
cv2.imwrite('newpad.jpg', pad)
# Out:
# True

# %%
# initialize the figure
fig = plt.figure("Images")
images = ("flipflop", flipflop), ("pad", pad), ("mouse", mouse)
# loop over the images
for (i, (name, image)) in enumerate(images):
	# show the image
	ax = fig.add_subplot(1, 3, i + 1)
	ax.set_title(name)
	plt.imshow(image, cmap = plt.cm.gray)
	plt.axis("off")
# show the figure
plt.show()
# compare the images
compare_images(flipflop, flipflop, "flipflop vs. flipflop")
compare_images(flipflop, pad, "flipflop vs. pad")
compare_images(flipflop, mouse, "flipflop vs. mouse")

# %%
# load the images -- the original, the original + contrast,
# and the original + photoshop
flipflop = cv2.imread("flipflop.png")
adidasshoe = cv2.imread("adidasshoe.png")
mouse = cv2.imread("mouse.png")
# convert the images to grayscale
flipflop = cv2.cvtColor(flipflop, cv2.COLOR_BGR2GRAY)
adidasshoe = cv2.cvtColor(adidasshoe, cv2.COLOR_BGR2GRAY)
mouse = cv2.cvtColor(mouse, cv2.COLOR_BGR2GRAY)

# %%
cv2.imwrite('newadidasshoe.jpg', adidasshoe)
# Out:
# True

# %%
# initialize the figure
fig = plt.figure("Images")
images = ("flipflop", flipflop), ("adidasshoe", adidasshoe), ("mouse", mouse)
# loop over the images
for (i, (name, image)) in enumerate(images):
	# show the image
	ax = fig.add_subplot(1, 3, i + 1)
	ax.set_title(name)
	plt.imshow(image, cmap = plt.cm.gray)
	plt.axis("off")
# show the figure
plt.show()
# compare the images
compare_images(flipflop, flipflop, "flipflop vs. flipflop")
compare_images(flipflop, adidasshoe, "flipflop vs. adidasshoe")
compare_images(flipflop, mouse, "flipflop vs. mouse")

# %%
# load the images -- the original, the original + contrast,
# and the original + photoshop p2,p3,p4
slippers = cv2.imread("slippers.png")
mouse = cv2.imread("mouse.png")
pad = cv2.imread("pad.png")
# convert the images to grayscale
slippers = cv2.cvtColor(slippers, cv2.COLOR_BGR2GRAY)
mouse = cv2.cvtColor(mouse, cv2.COLOR_BGR2GRAY)
pad = cv2.cvtColor(pad, cv2.COLOR_BGR2GRAY)

# %%
# initialize the figure
fig = plt.figure("Images")
images = ("slippers", slippers), ("mouse", mouse), ("pad", pad)
# loop over the images
for (i, (name, image)) in enumerate(images):
	# show the image
	ax = fig.add_subplot(1, 3, i + 1)
	ax.set_title(name)
	plt.imshow(image, cmap = plt.cm.gray)
	plt.axis("off")
# show the figure
plt.show()
# compare the images
compare_images(slippers, slippers, "slippers vs. slippers")
compare_images(slippers, mouse, "slippers vs. mouse")
compare_images(slippers, pad, "slippers vs. pad")

# %%
# load the images -- the original, the original + contrast,
# and the original + photoshop p2,p3,p5
slippers = cv2.imread("slippers.png")
mouse = cv2.imread("mouse.png")
adidasshoe = cv2.imread("adidasshoe.png")
# convert the images to grayscale
slippers = cv2.cvtColor(slippers, cv2.COLOR_BGR2GRAY)
mouse = cv2.cvtColor(mouse, cv2.COLOR_BGR2GRAY)
adidasshoe = cv2.cvtColor(adidasshoe, cv2.COLOR_BGR2GRAY)

# %%
# initialize the figure
fig = plt.figure("Images")
images = ("slippers", slippers), ("mouse", mouse), ("adidasshoe", adidasshoe)
# loop over the images
for (i, (name, image)) in enumerate(images):
	# show the image
	ax = fig.add_subplot(1, 3, i + 1)
	ax.set_title(name)
	plt.imshow(image, cmap = plt.cm.gray)
	plt.axis("off")
# show the figure
plt.show()
# compare the images
compare_images(slippers, slippers, "slippers vs. slippers")
compare_images(slippers, mouse, "slippers vs. mouse")
compare_images(slippers, adidasshoe, "slippers vs. adidasshoe")

# %%
# load the images -- the original, the original + contrast,
# and the original + photoshop p2,p3,p5
mouse = cv2.imread("mouse.png")
pad = cv2.imread("pad.png")
adidasshoe = cv2.imread("adidasshoe.png")
# convert the images to grayscale
mouse = cv2.cvtColor(mouse, cv2.COLOR_BGR2GRAY)
pad = cv2.cvtColor(pad, cv2.COLOR_BGR2GRAY)
adidasshoe = cv2.cvtColor(adidasshoe, cv2.COLOR_BGR2GRAY)

# %%
# initialize the figure
fig = plt.figure("Images")
images = ("mouse", mouse), ("pad", pad), ("adidasshoe", adidasshoe)
# loop over the images
for (i, (name, image)) in enumerate(images):
	# show the image
	ax = fig.add_subplot(1, 3, i + 1)
	ax.set_title(name)
	plt.imshow(image, cmap = plt.cm.gray)
	plt.axis("off")
# show the figure
plt.show()
# compare the images
compare_images(mouse, mouse, "mouse vs. mouse")
compare_images(mouse, pad, "mouse vs. pad")
compare_images(mouse, adidasshoe, "mouse vs. adidasshoe")

# %%
# load the images -- the original, the original + contrast,
# and the original + photoshop p2,p3,p5
pad = cv2.imread("pad.png")
mouse = cv2.imread("mouse.png")
adidasshoe = cv2.imread("adidasshoe.png")
# convert the images to grayscale
pad = cv2.cvtColor(pad, cv2.COLOR_BGR2GRAY)
mouse = cv2.cvtColor(mouse, cv2.COLOR_BGR2GRAY)
adidasshoe = cv2.cvtColor(adidasshoe, cv2.COLOR_BGR2GRAY)

# %%
# initialize the figure
fig = plt.figure("Images")
images = ("pad", pad), ("mouse", mouse), ("adidasshoe", adidasshoe)
# loop over the images
for (i, (name, image)) in enumerate(images):
	# show the image
	ax = fig.add_subplot(1, 3, i + 1)
	ax.set_title(name)
	plt.imshow(image, cmap = plt.cm.gray)
	plt.axis("off")
# show the figure
plt.show()
# compare the images
compare_images(pad, pad, "pad vs. pad")
compare_images(pad, mouse, "pad vs. mouse")
compare_images(pad, adidasshoe, "pad vs. adidasshoe")
